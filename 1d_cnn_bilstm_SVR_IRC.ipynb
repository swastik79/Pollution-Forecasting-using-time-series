# %%
import pandas as pd          
import numpy as np          # For mathematical calculations
import matplotlib.pyplot as plt  # For plotting graphs
from datetime import datetime    # To access datetime
from pandas import Series        # To work on series
import matplotlib
import warnings                   # To ignore the warnings
warnings.filterwarnings("ignore")
from math import sqrt
from sklearn.metrics import mean_squared_error
from numpy import array

#Reading Data
df = pd.read_excel('Merged_pollution_dataset - wo 2016 17.xlsx')
df_bbsr = df[(df['City/Town/Village/Area'] == 'Bhubaneswar') | (df['City/Town/Village/Area'] == 'Bhubaneshwar')]

df_bbsr.dtypes

df_bbsr['RSPM/PM10'] = pd.to_numeric(df_bbsr['RSPM/PM10'], errors='coerce')
df_bbsr['SO2'] = pd.to_numeric(df_bbsr['SO2'], errors='coerce')
df_bbsr['NO2'] = pd.to_numeric(df_bbsr['NO2'], errors='coerce')
df_bbsr['SPM'] = pd.to_numeric(df_bbsr['NO2'], errors='coerce')

df_bbsr.dtypes

#Data Preprocessing
df_bbsr['Location of Monitoring Station'].replace('SPCB Building, Bhubaneshwar', 'OSPCB Bldg',inplace=True)
df_bbsr['Location of Monitoring Station'].replace('Capital Police Station, Bhubaneshwar', 'Capital Police Stn.',inplace=True)
df_bbsr['Location of Monitoring Station'].replace('IRC Vilage, Bhubaneshwar', 'IRC',inplace=True)
df_bbsr['Location of Monitoring Station'].replace('Chandrasekharpur. Bhubneswar', 'Chandrasekharpur',inplace=True)
df_bbsr['Location of Monitoring Station'].replace('Water works, Palasuni, Bhubneswar', 'Palasuni',inplace=True)
df_bbsr['Location of Monitoring Station'].replace('Patrapada, Bhubneswar', 'Patrapada',inplace=True)

df_bbsr_irc = df_bbsr[(df_bbsr['Location of Monitoring Station'] == 'IRC')]

#Initial Analysis
#Checking the datatypes of various columns
df_bbsr_irc.dtypes

#Converting object to Datetime
df_bbsr_irc.reset_index(inplace = True)
df_bbsr_irc = df_bbsr_irc.drop(['index'], axis = 1)
df_bbsr_irc['Sampling Date'] = pd.to_datetime(df_bbsr_irc['Sampling Date'], format='%Y-%m-%d %H:%M')
df_bbsr_irc['Sampling Date'] = pd.to_datetime(df_bbsr_irc['Sampling Date'], format='%Y-%m-%d %H:%M')


df_bbsr_irc.dtypes

#Setting default Plot Size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15,8

print("SUCCESS!!")
df_bbsr_irc.head()
# Out:
# SUCCESS!!
#    Stn Code Sampling Date   State City/Town/Village/Area  \
# 0       NaN    2005-01-01  Orissa           Bhubaneshwar
# 1       NaN    2005-05-01  Orissa           Bhubaneshwar
# 2       NaN    2005-07-01  Orissa           Bhubaneshwar
# 3       NaN    2005-11-01  Orissa           Bhubaneshwar
# 4       NaN    2005-01-13  Orissa           Bhubaneshwar
#
#   Location of Monitoring Station                                Agency  \
# 0                            IRC  Odisha State Pollution Control Board
# 1                            IRC  Odisha State Pollution Control Board
# 2                            IRC  Odisha State Pollution Control Board
# 3                            IRC  Odisha State Pollution Control Board
# 4                            IRC  Odisha State Pollution Control Board
#
#          Type of Location  SO2   NO2  RSPM/PM10   SPM
# 0  Residential and others  NaN  14.0       98.0  14.0
# 1  Residential and others  NaN  27.0      130.0  27.0
# 2  Residential and others  NaN  24.0      183.0  24.0
# 3  Residential and others  NaN   NaN       85.0   NaN
# 4  Residential and others  NaN  11.0      102.0  11.0

# %%
#Index Sorting
df_bbsr_irc = df_bbsr_irc.set_index(df_bbsr_irc['Sampling Date'])
df_bbsr_irc = df_bbsr_irc.sort_index()
# plt.plot(df_bbsr_cps['NO2'])

#Separating Year, Month, Day and Day of Week
df_bbsr_irc['year'] = df_bbsr_irc['Sampling Date'].dt.year 
df_bbsr_irc['month'] = df_bbsr_irc['Sampling Date'].dt.month 
df_bbsr_irc['day'] = df_bbsr_irc['Sampling Date'].dt.day
df_bbsr_irc['day_of_week'] = df_bbsr_irc['Sampling Date'].dt.dayofweek

#Determining Weekend
def weekend(row):
    if (row == 5) or (row == 6):
        return 1
    else:
        return 0

df_bbsr_irc['weekend'] = df_bbsr_irc['day_of_week'].apply(weekend)

#Outlier Removal
mean_irc = df_bbsr_irc['SPM'].mean()
std_dev_irc = df_bbsr_irc['SPM'].std() #Standard Deviation of SPM

df_bbsr_irc['SPM'][df_bbsr_irc['SPM'] > (mean_irc + 2.5*std_dev_irc)] = np.nan   #Replacing Outlier with "nan"
plt.plot(df_bbsr_irc['SPM'])
df_bbsr_irc.isna().sum()

df_bbsr_irc['SPM'] = df_bbsr_irc['SPM'].fillna(method = 'backfill')   #Replacing "nan" with the previous values

#Dummy Encoding
df_bbsr_irc = pd.get_dummies( df_bbsr_irc, columns = ['month', 'day_of_week'] )

print("SUCCESS!!")
# Out:
# SUCCESS!!

# %%
#Creating Multi-features
xf = df_bbsr_irc[['weekend', 'month_1',
       'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7',
       'month_8', 'month_9', 'month_10', 'month_11', 'month_12',
       'day_of_week_0', 'day_of_week_1', 'day_of_week_2', 'day_of_week_3',
       'day_of_week_4', 'day_of_week_5', 'day_of_week_6', 'SPM']]

xf.head()
# Out:
#                weekend  month_1  month_2  month_3  month_4  month_5  month_6  \
# Sampling Date
# 2005-01-01           1        1        0        0        0        0        0
# 2005-01-02           1        1        0        0        0        0        0
# 2005-01-03           0        1        0        0        0        0        0
# 2005-01-08           1        1        0        0        0        0        0
# 2005-01-13           0        1        0        0        0        0        0
#
#                month_7  month_8  month_9  ...   month_11  month_12  \
# Sampling Date                             ...
# 2005-01-01           0        0        0  ...          0         0
# 2005-01-02           0        0        0  ...          0         0
# 2005-01-03           0        0        0  ...          0         0
# 2005-01-08           0        0        0  ...          0         0
# 2005-01-13           0        0        0  ...          0         0
#
#                day_of_week_0  day_of_week_1  day_of_week_2  day_of_week_3  \
# Sampling Date
# 2005-01-01                 0              0              0              0
# 2005-01-02                 0              0              0              0
# 2005-01-03                 1              0              0              0
# 2005-01-08                 0              0              0              0
# 2005-01-13                 0              0              0              1
#
#                day_of_week_4  day_of_week_5  day_of_week_6   SPM
# Sampling Date
# 2005-01-01                 0              1              0  14.0
# 2005-01-02                 0              0              1  19.0
# 2005-01-03                 0              0              0  19.0
# 2005-01-08                 0              1              0  15.0
# 2005-01-13                 0              0              0  11.0
#
# [5 rows x 21 columns]

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out-1
		# check if we are beyond the dataset
		if out_end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)


# choose a number of time steps
n_steps_in, n_steps_out = 100, 21

mean_spm = xf['SPM'].mean()
std_spm = xf['SPM'].std()

#Feature Scaling
cols = ['weekend', 'month_1',
       'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7',
       'month_8', 'month_9', 'month_10', 'month_11', 'month_12',
       'day_of_week_0', 'day_of_week_1', 'day_of_week_2', 'day_of_week_3',
       'day_of_week_4', 'day_of_week_5', 'day_of_week_6', 'SPM']

for field in cols:
    xf[field] = (xf[field] - xf[field].mean())/xf[field].std()


X, y = split_sequences(xf.values, n_steps_in, n_steps_out)

X_test, y_test = X[-1], y[-1]

X = np.delete(X, X.shape[0] - 1, 0)
y = np.delete(y, y.shape[0] - 1, 0)

# X = X.reshape(X.shape[0], X.shape[1], 1)
# y = y.reshape(y.shape[0], y.shape[1], 1)

n_features = X.shape[2]

print("SUCCESS!!")
# Out:
# SUCCESS!!

# %%
# %tensorflow_version 1.x
from keras import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import LSTM
# from keras.layers import GRU
from keras.layers.normalization import BatchNormalization
from keras.layers import Bidirectional


model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, padding='same', activation='relu', input_shape=(n_steps_in, n_features)))
model.add(MaxPooling1D(pool_size=2))
# model.add(BatchNormalization())

model.add(Conv1D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))

# model.add(Flatten())
# model.add(Dense(50, activation='relu'))
model.add(Bidirectional(LSTM(50, return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse')

print('SUCCESS!!')
# Out:
# SUCCESS!!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from tensorflow.python.keras.callbacks import EarlyStopping

monitor = EarlyStopping(monitor='loss', min_delta=1e-3, patience=50, verbose=1, mode='auto',
        restore_best_weights=True)
model.fit(X, y, callbacks=[monitor], verbose=2, epochs=2000)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/2000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 5s - loss: 1.0019
# Epoch 2/2000
#  - 2s - loss: 0.8937
# Epoch 3/2000
#  - 2s - loss: 0.7757
# Epoch 4/2000
#  - 2s - loss: 0.6957
# Epoch 5/2000
#  - 2s - loss: 0.6766
# Epoch 6/2000
#  - 2s - loss: 0.6639
# Epoch 7/2000
#  - 2s - loss: 0.6599
# Epoch 8/2000
#  - 2s - loss: 0.6512
# Epoch 9/2000
#  - 2s - loss: 0.6481
# Epoch 10/2000
#  - 2s - loss: 0.6429
# Epoch 11/2000
#  - 2s - loss: 0.6394
# Epoch 12/2000
#  - 2s - loss: 0.6364
# Epoch 13/2000
#  - 2s - loss: 0.6349
# Epoch 14/2000
#  - 2s - loss: 0.6330
# Epoch 15/2000
#  - 2s - loss: 0.6313
# Epoch 16/2000
#  - 2s - loss: 0.6296
# Epoch 17/2000
#  - 2s - loss: 0.6267
# Epoch 18/2000
#  - 2s - loss: 0.6258
# Epoch 19/2000
#  - 2s - loss: 0.6237
# Epoch 20/2000
#  - 2s - loss: 0.6200
# Epoch 21/2000
#  - 2s - loss: 0.6183
# Epoch 22/2000
#  - 2s - loss: 0.6147
# Epoch 23/2000
#  - 2s - loss: 0.6117
# Epoch 24/2000
#  - 2s - loss: 0.6096
# Epoch 25/2000
#  - 2s - loss: 0.6041
# Epoch 26/2000
#  - 2s - loss: 0.5988
# Epoch 27/2000
#  - 2s - loss: 0.5931
# Epoch 28/2000
#  - 2s - loss: 0.5897
# Epoch 29/2000
#  - 2s - loss: 0.5862
# Epoch 30/2000
#  - 2s - loss: 0.5799
# Epoch 31/2000
#  - 2s - loss: 0.5770
# Epoch 32/2000
#  - 2s - loss: 0.5712
# Epoch 33/2000
#  - 2s - loss: 0.5653
# Epoch 34/2000
#  - 2s - loss: 0.5602
# Epoch 35/2000
#  - 2s - loss: 0.5577
# Epoch 36/2000
#  - 2s - loss: 0.5469
# Epoch 37/2000
#  - 2s - loss: 0.5405
# Epoch 38/2000
#  - 2s - loss: 0.5363
# Epoch 39/2000
#  - 2s - loss: 0.5310
# Epoch 40/2000
#  - 2s - loss: 0.5205
# Epoch 41/2000
#  - 2s - loss: 0.5140
# Epoch 42/2000
#  - 2s - loss: 0.5068
# Epoch 43/2000
#  - 2s - loss: 0.5027
# Epoch 44/2000
#  - 2s - loss: 0.4863
# Epoch 45/2000
#  - 2s - loss: 0.4793
# Epoch 46/2000
#  - 2s - loss: 0.4683
# Epoch 47/2000
#  - 2s - loss: 0.4559
# Epoch 48/2000
#  - 2s - loss: 0.4507
# Epoch 49/2000
#  - 2s - loss: 0.4385
# Epoch 50/2000
#  - 2s - loss: 0.4279
# Epoch 51/2000
#  - 2s - loss: 0.4254
# Epoch 52/2000
#  - 2s - loss: 0.4162
# Epoch 53/2000
#  - 2s - loss: 0.4113
# Epoch 54/2000
#  - 2s - loss: 0.4059
# Epoch 55/2000
#  - 2s - loss: 0.3983
# Epoch 56/2000
#  - 2s - loss: 0.3942
# Epoch 57/2000
#  - 2s - loss: 0.3881
# Epoch 58/2000
#  - 2s - loss: 0.3826
# Epoch 59/2000
#  - 2s - loss: 0.3768
# Epoch 60/2000
#  - 2s - loss: 0.3720
# Epoch 61/2000
#  - 2s - loss: 0.3686
# Epoch 62/2000
#  - 2s - loss: 0.3680
# Epoch 63/2000
#  - 2s - loss: 0.3604
# Epoch 64/2000
#  - 2s - loss: 0.3542
# Epoch 65/2000
#  - 2s - loss: 0.3514
# Epoch 66/2000
#  - 2s - loss: 0.3518
# Epoch 67/2000
#  - 2s - loss: 0.3503
# Epoch 68/2000
#  - 2s - loss: 0.3468
# Epoch 69/2000
#  - 2s - loss: 0.3418
# Epoch 70/2000
#  - 2s - loss: 0.3352
# Epoch 71/2000
#  - 2s - loss: 0.3303
# Epoch 72/2000
#  - 2s - loss: 0.3230
# Epoch 73/2000
#  - 2s - loss: 0.3179
# Epoch 74/2000
#  - 2s - loss: 0.3151
# Epoch 75/2000
#  - 2s - loss: 0.3110
# Epoch 76/2000
#  - 2s - loss: 0.3073
# Epoch 77/2000
#  - 2s - loss: 0.3050
# Epoch 78/2000
#  - 2s - loss: 0.3021
# Epoch 79/2000
#  - 2s - loss: 0.3003
# Epoch 80/2000
#  - 2s - loss: 0.2994
# Epoch 81/2000
#  - 2s - loss: 0.2947
# Epoch 82/2000
#  - 2s - loss: 0.2882
# Epoch 83/2000
#  - 2s - loss: 0.2863
# Epoch 84/2000
#  - 2s - loss: 0.2815
# Epoch 85/2000
#  - 2s - loss: 0.2777
# Epoch 86/2000
#  - 2s - loss: 0.2757
# Epoch 87/2000
#  - 2s - loss: 0.2723
# Epoch 88/2000
#  - 2s - loss: 0.2677
# Epoch 89/2000
#  - 2s - loss: 0.2636
# Epoch 90/2000
#  - 2s - loss: 0.2639
# Epoch 91/2000
#  - 2s - loss: 0.2622
# Epoch 92/2000
#  - 2s - loss: 0.2624
# Epoch 93/2000
#  - 2s - loss: 0.2591
# Epoch 94/2000
#  - 2s - loss: 0.2541
# Epoch 95/2000
#  - 2s - loss: 0.2492
# Epoch 96/2000
#  - 2s - loss: 0.2450
# Epoch 97/2000
#  - 2s - loss: 0.2416
# Epoch 98/2000
#  - 2s - loss: 0.2387
# Epoch 99/2000
#  - 2s - loss: 0.2345
# Epoch 100/2000
#  - 2s - loss: 0.2333
# Epoch 101/2000
#  - 2s - loss: 0.2320
# Epoch 102/2000
#  - 2s - loss: 0.2277
# Epoch 103/2000
#  - 2s - loss: 0.2234
# Epoch 104/2000
#  - 2s - loss: 0.2218
# Epoch 105/2000
#  - 2s - loss: 0.2168
# Epoch 106/2000
#  - 2s - loss: 0.2145
# Epoch 107/2000
#  - 2s - loss: 0.2107
# Epoch 108/2000
#  - 2s - loss: 0.2094
# Epoch 109/2000
#  - 2s - loss: 0.2069
# Epoch 110/2000
#  - 2s - loss: 0.2072
# Epoch 111/2000
#  - 2s - loss: 0.2048
# Epoch 112/2000
#  - 2s - loss: 0.2035
# Epoch 113/2000
#  - 2s - loss: 0.2014
# Epoch 114/2000
#  - 2s - loss: 0.1993
# Epoch 115/2000
#  - 2s - loss: 0.1956
# Epoch 116/2000
#  - 2s - loss: 0.1920
# Epoch 117/2000
#  - 2s - loss: 0.1892
# Epoch 118/2000
#  - 2s - loss: 0.1852
# Epoch 119/2000
#  - 2s - loss: 0.1801
# Epoch 120/2000
#  - 2s - loss: 0.1771
# Epoch 121/2000
#  - 2s - loss: 0.1770
# Epoch 122/2000
#  - 2s - loss: 0.1768
# Epoch 123/2000
#  - 2s - loss: 0.1746
# Epoch 124/2000
#  - 2s - loss: 0.1704
# Epoch 125/2000
#  - 2s - loss: 0.1670
# Epoch 126/2000
#  - 2s - loss: 0.1652
# Epoch 127/2000
#  - 2s - loss: 0.1645
# Epoch 128/2000
#  - 2s - loss: 0.1615
# Epoch 129/2000
#  - 2s - loss: 0.1593
# Epoch 130/2000
#  - 2s - loss: 0.1559
# Epoch 131/2000
#  - 2s - loss: 0.1539
# Epoch 132/2000
#  - 2s - loss: 0.1538
# Epoch 133/2000
#  - 2s - loss: 0.1503
# Epoch 134/2000
#  - 2s - loss: 0.1490
# Epoch 135/2000
#  - 2s - loss: 0.1447
# Epoch 136/2000
#  - 2s - loss: 0.1429
# Epoch 137/2000
#  - 2s - loss: 0.1393
# Epoch 138/2000
#  - 2s - loss: 0.1379
# Epoch 139/2000
#  - 2s - loss: 0.1386
# Epoch 140/2000
#  - 2s - loss: 0.1379
# Epoch 141/2000
#  - 2s - loss: 0.1350
# Epoch 142/2000
#  - 2s - loss: 0.1329
# Epoch 143/2000
#  - 2s - loss: 0.1313
# Epoch 144/2000
#  - 2s - loss: 0.1296
# Epoch 145/2000
#  - 2s - loss: 0.1273
# Epoch 146/2000
#  - 2s - loss: 0.1260
# Epoch 147/2000
#  - 2s - loss: 0.1239
# Epoch 148/2000
#  - 2s - loss: 0.1260
# Epoch 149/2000
#  - 2s - loss: 0.1218
# Epoch 150/2000
#  - 2s - loss: 0.1198
# Epoch 151/2000
#  - 2s - loss: 0.1183
# Epoch 152/2000
#  - 2s - loss: 0.1145
# Epoch 153/2000
#  - 3s - loss: 0.1112
# Epoch 154/2000
#  - 4s - loss: 0.1096
# Epoch 155/2000
#  - 4s - loss: 0.1073
# Epoch 156/2000
#  - 2s - loss: 0.1068
# Epoch 157/2000
#  - 2s - loss: 0.1095
# Epoch 158/2000
#  - 2s - loss: 0.1094
# Epoch 159/2000
#  - 2s - loss: 0.1081
# Epoch 160/2000
#  - 2s - loss: 0.1077
# Epoch 161/2000
#  - 2s - loss: 0.1032
# Epoch 162/2000
#  - 2s - loss: 0.1012
# Epoch 163/2000
#  - 2s - loss: 0.0989
# Epoch 164/2000
#  - 2s - loss: 0.0956
# Epoch 165/2000
#  - 2s - loss: 0.0947
# Epoch 166/2000
#  - 2s - loss: 0.0940
# Epoch 167/2000
#  - 2s - loss: 0.0920
# Epoch 168/2000
#  - 2s - loss: 0.0914
# Epoch 169/2000
#  - 2s - loss: 0.0916
# Epoch 170/2000
#  - 2s - loss: 0.0906
# Epoch 171/2000
#  - 2s - loss: 0.0906
# Epoch 172/2000
#  - 2s - loss: 0.0907
# Epoch 173/2000
#  - 2s - loss: 0.0883
# Epoch 174/2000
#  - 2s - loss: 0.0870
# Epoch 175/2000
#  - 2s - loss: 0.0853
# Epoch 176/2000
#  - 2s - loss: 0.0833
# Epoch 177/2000
#  - 2s - loss: 0.0811
# Epoch 178/2000
#  - 2s - loss: 0.0809
# Epoch 179/2000
#  - 2s - loss: 0.0806
# Epoch 180/2000
#  - 2s - loss: 0.0795
# Epoch 181/2000
#  - 2s - loss: 0.0787
# Epoch 182/2000
#  - 2s - loss: 0.0809
# Epoch 183/2000
#  - 2s - loss: 0.0816
# Epoch 184/2000
#  - 2s - loss: 0.0817
# Epoch 185/2000
#  - 2s - loss: 0.0796
# Epoch 186/2000
#  - 2s - loss: 0.0768
# Epoch 187/2000
#  - 2s - loss: 0.0736
# Epoch 188/2000
#  - 2s - loss: 0.0711
# Epoch 189/2000
#  - 2s - loss: 0.0712
# Epoch 190/2000
#  - 2s - loss: 0.0706
# Epoch 191/2000
#  - 2s - loss: 0.0712
# Epoch 192/2000
#  - 2s - loss: 0.0711
# Epoch 193/2000
#  - 2s - loss: 0.0702
# Epoch 194/2000
#  - 2s - loss: 0.0690
# Epoch 195/2000
#  - 2s - loss: 0.0693
# Epoch 196/2000
#  - 2s - loss: 0.0700
# Epoch 197/2000
#  - 2s - loss: 0.0679
# Epoch 198/2000
#  - 2s - loss: 0.0694
# Epoch 199/2000
#  - 2s - loss: 0.0687
# Epoch 200/2000
#  - 2s - loss: 0.0673
# Epoch 201/2000
#  - 2s - loss: 0.0643
# Epoch 202/2000
#  - 2s - loss: 0.0637
# Epoch 203/2000
#  - 2s - loss: 0.0631
# Epoch 204/2000
#  - 2s - loss: 0.0617
# Epoch 205/2000
#  - 2s - loss: 0.0593
# Epoch 206/2000
#  - 2s - loss: 0.0592
# Epoch 207/2000
#  - 2s - loss: 0.0593
# Epoch 208/2000
#  - 2s - loss: 0.0580
# Epoch 209/2000
#  - 2s - loss: 0.0569
# Epoch 210/2000
#  - 2s - loss: 0.0559
# Epoch 211/2000
#  - 2s - loss: 0.0564
# Epoch 212/2000
#  - 2s - loss: 0.0557
# Epoch 213/2000
#  - 2s - loss: 0.0544
# Epoch 214/2000
#  - 2s - loss: 0.0532
# Epoch 215/2000
#  - 2s - loss: 0.0526
# Epoch 216/2000
#  - 2s - loss: 0.0519
# Epoch 217/2000
#  - 2s - loss: 0.0528
# Epoch 218/2000
#  - 2s - loss: 0.0532
# Epoch 219/2000
#  - 2s - loss: 0.0531
# Epoch 220/2000
#  - 2s - loss: 0.0527
# Epoch 221/2000
#  - 2s - loss: 0.0530
# Epoch 222/2000
#  - 2s - loss: 0.0544
# Epoch 223/2000
#  - 2s - loss: 0.0539
# Epoch 224/2000
#  - 2s - loss: 0.0521
# Epoch 225/2000
#  - 2s - loss: 0.0526
# Epoch 226/2000
#  - 2s - loss: 0.0537
# Epoch 227/2000
#  - 2s - loss: 0.0542
# Epoch 228/2000
#  - 2s - loss: 0.0528
# Epoch 229/2000
#  - 2s - loss: 0.0490
# Epoch 230/2000
#  - 2s - loss: 0.0464
# Epoch 231/2000
#  - 2s - loss: 0.0448
# Epoch 232/2000
#  - 2s - loss: 0.0444
# Epoch 233/2000
#  - 2s - loss: 0.0435
# Epoch 234/2000
#  - 2s - loss: 0.0446
# Epoch 235/2000
#  - 2s - loss: 0.0446
# Epoch 236/2000
#  - 2s - loss: 0.0434
# Epoch 237/2000
#  - 2s - loss: 0.0416
# Epoch 238/2000
#  - 2s - loss: 0.0411
# Epoch 239/2000
#  - 2s - loss: 0.0410
# Epoch 240/2000
#  - 2s - loss: 0.0413
# Epoch 241/2000
#  - 2s - loss: 0.0419
# Epoch 242/2000
#  - 2s - loss: 0.0417
# Epoch 243/2000
#  - 2s - loss: 0.0433
# Epoch 244/2000
#  - 2s - loss: 0.0442
# Epoch 245/2000
#  - 2s - loss: 0.0454
# Epoch 246/2000
#  - 2s - loss: 0.0439
# Epoch 247/2000
#  - 2s - loss: 0.0444
# Epoch 248/2000
#  - 2s - loss: 0.0449
# Epoch 249/2000
#  - 2s - loss: 0.0452
# Epoch 250/2000
#  - 2s - loss: 0.0476
# Epoch 251/2000
#  - 2s - loss: 0.0475
# Epoch 252/2000
#  - 2s - loss: 0.0509
# Epoch 253/2000
#  - 2s - loss: 0.0516
# Epoch 254/2000
#  - 2s - loss: 0.0497
# Epoch 255/2000
#  - 2s - loss: 0.0458
# Epoch 256/2000
#  - 2s - loss: 0.0419
# Epoch 257/2000
#  - 2s - loss: 0.0401
# Epoch 258/2000
#  - 2s - loss: 0.0376
# Epoch 259/2000
#  - 2s - loss: 0.0353
# Epoch 260/2000
#  - 2s - loss: 0.0343
# Epoch 261/2000
#  - 2s - loss: 0.0335
# Epoch 262/2000
#  - 2s - loss: 0.0328
# Epoch 263/2000
#  - 2s - loss: 0.0322
# Epoch 264/2000
#  - 2s - loss: 0.0310
# Epoch 265/2000
#  - 2s - loss: 0.0315
# Epoch 266/2000
#  - 2s - loss: 0.0317
# Epoch 267/2000
#  - 2s - loss: 0.0325
# Epoch 268/2000
#  - 2s - loss: 0.0328
# Epoch 269/2000
#  - 2s - loss: 0.0343
# Epoch 270/2000
#  - 2s - loss: 0.0348
# Epoch 271/2000
#  - 2s - loss: 0.0352
# Epoch 272/2000
#  - 2s - loss: 0.0349
# Epoch 273/2000
#  - 2s - loss: 0.0354
# Epoch 274/2000
#  - 2s - loss: 0.0358
# Epoch 275/2000
#  - 2s - loss: 0.0381
# Epoch 276/2000
#  - 2s - loss: 0.0376
# Epoch 277/2000
#  - 2s - loss: 0.0364
# Epoch 278/2000
#  - 2s - loss: 0.0355
# Epoch 279/2000
#  - 2s - loss: 0.0325
# Epoch 280/2000
#  - 2s - loss: 0.0324
# Epoch 281/2000
#  - 2s - loss: 0.0322
# Epoch 282/2000
#  - 2s - loss: 0.0316
# Epoch 283/2000
#  - 2s - loss: 0.0312
# Epoch 284/2000
#  - 2s - loss: 0.0301
# Epoch 285/2000
#  - 2s - loss: 0.0304
# Epoch 286/2000
#  - 2s - loss: 0.0315
# Epoch 287/2000
#  - 2s - loss: 0.0314
# Epoch 288/2000
#  - 2s - loss: 0.0320
# Epoch 289/2000
#  - 2s - loss: 0.0330
# Epoch 290/2000
#  - 2s - loss: 0.0314
# Epoch 291/2000
#  - 2s - loss: 0.0303
# Epoch 292/2000
#  - 2s - loss: 0.0294
# Epoch 293/2000
#  - 2s - loss: 0.0286
# Epoch 294/2000
#  - 2s - loss: 0.0277
# Epoch 295/2000
#  - 2s - loss: 0.0280
# Epoch 296/2000
#  - 2s - loss: 0.0275
# Epoch 297/2000
#  - 2s - loss: 0.0272
# Epoch 298/2000
#  - 2s - loss: 0.0265
# Epoch 299/2000
#  - 2s - loss: 0.0269
# Epoch 300/2000
#  - 2s - loss: 0.0280
# Epoch 301/2000
#  - 2s - loss: 0.0280
# Epoch 302/2000
#  - 2s - loss: 0.0280
# Epoch 303/2000
#  - 2s - loss: 0.0284
# Epoch 304/2000
#  - 2s - loss: 0.0281
# Epoch 305/2000
#  - 2s - loss: 0.0274
# Epoch 306/2000
#  - 2s - loss: 0.0283
# Epoch 307/2000
#  - 2s - loss: 0.0292
# Epoch 308/2000
#  - 2s - loss: 0.0304
# Epoch 309/2000
#  - 2s - loss: 0.0293
# Epoch 310/2000
#  - 2s - loss: 0.0289
# Epoch 311/2000
#  - 2s - loss: 0.0298
# Epoch 312/2000
#  - 2s - loss: 0.0311
# Epoch 313/2000
#  - 2s - loss: 0.0314
# Epoch 314/2000
#  - 2s - loss: 0.0305
# Epoch 315/2000
#  - 2s - loss: 0.0292
# Epoch 316/2000
#  - 2s - loss: 0.0283
# Epoch 317/2000
#  - 2s - loss: 0.0278
# Epoch 318/2000
#  - 2s - loss: 0.0274
# Epoch 319/2000
#  - 2s - loss: 0.0270
# Epoch 320/2000
#  - 2s - loss: 0.0260
# Epoch 321/2000
#  - 2s - loss: 0.0243
# Epoch 322/2000
#  - 2s - loss: 0.0239
# Epoch 323/2000
#  - 2s - loss: 0.0240
# Epoch 324/2000
#  - 2s - loss: 0.0245
# Epoch 325/2000
#  - 2s - loss: 0.0247
# Epoch 326/2000
#  - 2s - loss: 0.0245
# Epoch 327/2000
#  - 2s - loss: 0.0255
# Epoch 328/2000
#  - 2s - loss: 0.0254
# Epoch 329/2000
#  - 2s - loss: 0.0256
# Epoch 330/2000
#  - 2s - loss: 0.0235
# Epoch 331/2000
#  - 2s - loss: 0.0228
# Epoch 332/2000
#  - 2s - loss: 0.0237
# Epoch 333/2000
#  - 2s - loss: 0.0234
# Epoch 334/2000
#  - 2s - loss: 0.0238
# Epoch 335/2000
#  - 2s - loss: 0.0241
# Epoch 336/2000
#  - 2s - loss: 0.0247
# Epoch 337/2000
#  - 2s - loss: 0.0240
# Epoch 338/2000
#  - 2s - loss: 0.0237
# Epoch 339/2000
#  - 2s - loss: 0.0236
# Epoch 340/2000
#  - 2s - loss: 0.0237
# Epoch 341/2000
#  - 2s - loss: 0.0243
# Epoch 342/2000
#  - 2s - loss: 0.0250
# Epoch 343/2000
#  - 2s - loss: 0.0245
# Epoch 344/2000
#  - 2s - loss: 0.0238
# Epoch 345/2000
#  - 2s - loss: 0.0238
# Epoch 346/2000
#  - 2s - loss: 0.0240
# Epoch 347/2000
#  - 2s - loss: 0.0236
# Epoch 348/2000
#  - 2s - loss: 0.0246
# Epoch 349/2000
#  - 2s - loss: 0.0246
# Epoch 350/2000
#  - 2s - loss: 0.0244
# Epoch 351/2000
#  - 2s - loss: 0.0239
# Epoch 352/2000
#  - 2s - loss: 0.0239
# Epoch 353/2000
#  - 2s - loss: 0.0233
# Epoch 354/2000
#  - 2s - loss: 0.0233
# Epoch 355/2000
#  - 2s - loss: 0.0247
# Epoch 356/2000
#  - 2s - loss: 0.0255
# Epoch 357/2000
#  - 2s - loss: 0.0253
# Epoch 358/2000
#  - 2s - loss: 0.0247
# Epoch 359/2000
#  - 2s - loss: 0.0241
# Epoch 360/2000
#  - 2s - loss: 0.0230
# Epoch 361/2000
#  - 2s - loss: 0.0244
# Epoch 362/2000
#  - 2s - loss: 0.0252
# Epoch 363/2000
#  - 2s - loss: 0.0244
# Epoch 364/2000
#  - 2s - loss: 0.0233
# Epoch 365/2000
#  - 2s - loss: 0.0219
# Epoch 366/2000
#  - 2s - loss: 0.0225
# Epoch 367/2000
#  - 2s - loss: 0.0213
# Epoch 368/2000
#  - 2s - loss: 0.0204
# Epoch 369/2000
#  - 2s - loss: 0.0197
# Epoch 370/2000
#  - 2s - loss: 0.0187
# Epoch 371/2000
#  - 2s - loss: 0.0182
# Epoch 372/2000
#  - 2s - loss: 0.0176
# Epoch 373/2000
#  - 2s - loss: 0.0186
# Epoch 374/2000
#  - 2s - loss: 0.0190
# Epoch 375/2000
#  - 2s - loss: 0.0191
# Epoch 376/2000
#  - 2s - loss: 0.0201
# Epoch 377/2000
#  - 2s - loss: 0.0211
# Epoch 378/2000
#  - 2s - loss: 0.0202
# Epoch 379/2000
#  - 2s - loss: 0.0197
# Epoch 380/2000
#  - 2s - loss: 0.0195
# Epoch 381/2000
#  - 2s - loss: 0.0183
# Epoch 382/2000
#  - 2s - loss: 0.0181
# Epoch 383/2000
#  - 2s - loss: 0.0184
# Epoch 384/2000
#  - 2s - loss: 0.0179
# Epoch 385/2000
#  - 2s - loss: 0.0177
# Epoch 386/2000
#  - 2s - loss: 0.0184
# Epoch 387/2000
#  - 2s - loss: 0.0189
# Epoch 388/2000
#  - 2s - loss: 0.0191
# Epoch 389/2000
#  - 2s - loss: 0.0187
# Epoch 390/2000
#  - 2s - loss: 0.0184
# Epoch 391/2000
#  - 2s - loss: 0.0187
# Epoch 392/2000
#  - 2s - loss: 0.0187
# Epoch 393/2000
#  - 2s - loss: 0.0193
# Epoch 394/2000
#  - 2s - loss: 0.0197
# Epoch 395/2000
#  - 2s - loss: 0.0201
# Epoch 396/2000
#  - 2s - loss: 0.0207
# Epoch 397/2000
#  - 2s - loss: 0.0203
# Epoch 398/2000
#  - 2s - loss: 0.0199
# Epoch 399/2000
#  - 2s - loss: 0.0207
# Epoch 400/2000
#  - 2s - loss: 0.0204
# Epoch 401/2000
#  - 2s - loss: 0.0210
# Epoch 402/2000
#  - 2s - loss: 0.0198
# Epoch 403/2000
#  - 2s - loss: 0.0194
# Epoch 404/2000
#  - 2s - loss: 0.0202
# Epoch 405/2000
#  - 2s - loss: 0.0200
# Epoch 406/2000
#  - 2s - loss: 0.0206
# Epoch 407/2000
#  - 2s - loss: 0.0210
# Epoch 408/2000
#  - 2s - loss: 0.0205
# Epoch 409/2000
#  - 2s - loss: 0.0204
# Epoch 410/2000
#  - 2s - loss: 0.0205
# Epoch 411/2000
#  - 2s - loss: 0.0201
# Epoch 412/2000
#  - 2s - loss: 0.0201
# Epoch 413/2000
#  - 2s - loss: 0.0193
# Epoch 414/2000
#  - 2s - loss: 0.0186
# Epoch 415/2000
#  - 2s - loss: 0.0182
# Epoch 416/2000
#  - 2s - loss: 0.0169
# Epoch 417/2000
#  - 2s - loss: 0.0162
# Epoch 418/2000
#  - 2s - loss: 0.0167
# Epoch 419/2000
#  - 2s - loss: 0.0168
# Epoch 420/2000
#  - 2s - loss: 0.0172
# Epoch 421/2000
#  - 2s - loss: 0.0174
# Epoch 422/2000
#  - 2s - loss: 0.0169
# Epoch 423/2000
#  - 2s - loss: 0.0167
# Epoch 424/2000
#  - 2s - loss: 0.0160
# Epoch 425/2000
#  - 2s - loss: 0.0158
# Epoch 426/2000
#  - 2s - loss: 0.0169
# Epoch 427/2000
#  - 4s - loss: 0.0174
# Epoch 428/2000
#  - 4s - loss: 0.0176
# Epoch 429/2000
#  - 4s - loss: 0.0179
# Epoch 430/2000
#  - 2s - loss: 0.0182
# Epoch 431/2000
#  - 2s - loss: 0.0180
# Epoch 432/2000
#  - 2s - loss: 0.0180
# Epoch 433/2000
#  - 2s - loss: 0.0186
# Epoch 434/2000
#  - 2s - loss: 0.0189
# Epoch 435/2000
#  - 2s - loss: 0.0183
# Epoch 436/2000
#  - 2s - loss: 0.0178
# Epoch 437/2000
#  - 2s - loss: 0.0183
# Epoch 438/2000
#  - 2s - loss: 0.0177
# Epoch 439/2000
#  - 2s - loss: 0.0167
# Epoch 440/2000
#  - 2s - loss: 0.0165
# Epoch 441/2000
#  - 2s - loss: 0.0158
# Epoch 442/2000
#  - 2s - loss: 0.0146
# Epoch 443/2000
#  - 2s - loss: 0.0144
# Epoch 444/2000
#  - 2s - loss: 0.0152
# Epoch 445/2000
#  - 2s - loss: 0.0160
# Epoch 446/2000
#  - 2s - loss: 0.0161
# Epoch 447/2000
#  - 2s - loss: 0.0161
# Epoch 448/2000
#  - 2s - loss: 0.0167
# Epoch 449/2000
#  - 2s - loss: 0.0168
# Epoch 450/2000
#  - 2s - loss: 0.0168
# Epoch 451/2000
#  - 2s - loss: 0.0168
# Epoch 452/2000
#  - 2s - loss: 0.0171
# Epoch 453/2000
#  - 2s - loss: 0.0166
# Epoch 454/2000
#  - 2s - loss: 0.0157
# Epoch 455/2000
#  - 2s - loss: 0.0163
# Epoch 456/2000
#  - 2s - loss: 0.0164
# Epoch 457/2000
#  - 2s - loss: 0.0167
# Epoch 458/2000
#  - 2s - loss: 0.0173
# Epoch 459/2000
#  - 2s - loss: 0.0180
# Epoch 460/2000
#  - 2s - loss: 0.0184
# Epoch 461/2000
#  - 2s - loss: 0.0180
# Epoch 462/2000
#  - 2s - loss: 0.0185
# Epoch 463/2000
#  - 2s - loss: 0.0180
# Epoch 464/2000
#  - 2s - loss: 0.0168
# Epoch 465/2000
#  - 2s - loss: 0.0159
# Epoch 466/2000
#  - 2s - loss: 0.0149
# Epoch 467/2000
#  - 2s - loss: 0.0157
# Epoch 468/2000
#  - 2s - loss: 0.0155
# Epoch 469/2000
#  - 2s - loss: 0.0155
# Epoch 470/2000
#  - 2s - loss: 0.0154
# Epoch 471/2000
#  - 2s - loss: 0.0152
# Epoch 472/2000
#  - 2s - loss: 0.0153
# Epoch 473/2000
#  - 2s - loss: 0.0144
# Epoch 474/2000
#  - 2s - loss: 0.0145
# Epoch 475/2000
#  - 2s - loss: 0.0141
# Epoch 476/2000
#  - 2s - loss: 0.0136
# Epoch 477/2000
#  - 2s - loss: 0.0135
# Epoch 478/2000
#  - 2s - loss: 0.0134
# Epoch 479/2000
#  - 2s - loss: 0.0140
# Epoch 480/2000
#  - 2s - loss: 0.0143
# Epoch 481/2000
#  - 2s - loss: 0.0149
# Epoch 482/2000
#  - 2s - loss: 0.0148
# Epoch 483/2000
#  - 2s - loss: 0.0148
# Epoch 484/2000
#  - 2s - loss: 0.0153
# Epoch 485/2000
#  - 2s - loss: 0.0150
# Epoch 486/2000
#  - 2s - loss: 0.0156
# Epoch 487/2000
#  - 2s - loss: 0.0160
# Epoch 488/2000
#  - 2s - loss: 0.0150
# Epoch 489/2000
#  - 2s - loss: 0.0153
# Epoch 490/2000
#  - 2s - loss: 0.0161
# Epoch 491/2000
#  - 2s - loss: 0.0161
# Epoch 492/2000
#  - 2s - loss: 0.0159
# Epoch 493/2000
#  - 2s - loss: 0.0156
# Epoch 494/2000
#  - 2s - loss: 0.0156
# Epoch 495/2000
#  - 2s - loss: 0.0158
# Epoch 496/2000
#  - 2s - loss: 0.0156
# Epoch 497/2000
#  - 2s - loss: 0.0151
# Epoch 498/2000
#  - 2s - loss: 0.0146
# Epoch 499/2000
#  - 2s - loss: 0.0144
# Epoch 500/2000
#  - 2s - loss: 0.0143
# Epoch 501/2000
#  - 2s - loss: 0.0148
# Epoch 502/2000
#  - 2s - loss: 0.0142
# Epoch 503/2000
#  - 2s - loss: 0.0148
# Epoch 504/2000
#  - 2s - loss: 0.0142
# Epoch 505/2000
#  - 2s - loss: 0.0144
# Epoch 506/2000
#  - 2s - loss: 0.0137
# Epoch 507/2000
#  - 2s - loss: 0.0129
# Epoch 508/2000
#  - 2s - loss: 0.0129
# Epoch 509/2000
#  - 2s - loss: 0.0125
# Epoch 510/2000
#  - 2s - loss: 0.0116
# Epoch 511/2000
#  - 2s - loss: 0.0109
# Epoch 512/2000
#  - 2s - loss: 0.0111
# Epoch 513/2000
#  - 2s - loss: 0.0114
# Epoch 514/2000
#  - 2s - loss: 0.0114
# Epoch 515/2000
#  - 2s - loss: 0.0117
# Epoch 516/2000
#  - 2s - loss: 0.0116
# Epoch 517/2000
#  - 2s - loss: 0.0120
# Epoch 518/2000
#  - 2s - loss: 0.0121
# Epoch 519/2000
#  - 2s - loss: 0.0129
# Epoch 520/2000
#  - 2s - loss: 0.0140
# Epoch 521/2000
#  - 2s - loss: 0.0143
# Epoch 522/2000
#  - 2s - loss: 0.0148
# Epoch 523/2000
#  - 2s - loss: 0.0147
# Epoch 524/2000
#  - 2s - loss: 0.0153
# Epoch 525/2000
#  - 2s - loss: 0.0147
# Epoch 526/2000
#  - 2s - loss: 0.0139
# Epoch 527/2000
#  - 2s - loss: 0.0141
# Epoch 528/2000
#  - 2s - loss: 0.0147
# Epoch 529/2000
#  - 2s - loss: 0.0143
# Epoch 530/2000
#  - 2s - loss: 0.0143
# Epoch 531/2000
#  - 2s - loss: 0.0140
# Epoch 532/2000
#  - 2s - loss: 0.0140
# Epoch 533/2000
#  - 2s - loss: 0.0139
# Epoch 534/2000
#  - 2s - loss: 0.0138
# Epoch 535/2000
#  - 2s - loss: 0.0140
# Epoch 536/2000
#  - 2s - loss: 0.0143
# Epoch 537/2000
#  - 2s - loss: 0.0156
# Epoch 538/2000
#  - 2s - loss: 0.0163
# Epoch 539/2000
#  - 2s - loss: 0.0172
# Epoch 540/2000
#  - 2s - loss: 0.0165
# Epoch 541/2000
#  - 2s - loss: 0.0160
# Epoch 542/2000
#  - 2s - loss: 0.0146
# Epoch 543/2000
#  - 2s - loss: 0.0135
# Epoch 544/2000
#  - 2s - loss: 0.0125
# Epoch 545/2000
#  - 2s - loss: 0.0119
# Epoch 546/2000
#  - 2s - loss: 0.0113
# Epoch 547/2000
#  - 2s - loss: 0.0109
# Epoch 548/2000
#  - 2s - loss: 0.0108
# Epoch 549/2000
#  - 2s - loss: 0.0111
# Epoch 550/2000
#  - 2s - loss: 0.0110
# Epoch 551/2000
#  - 2s - loss: 0.0111
# Epoch 552/2000
#  - 2s - loss: 0.0110
# Epoch 553/2000
#  - 2s - loss: 0.0107
# Epoch 554/2000
#  - 2s - loss: 0.0109
# Epoch 555/2000
#  - 2s - loss: 0.0108
# Epoch 556/2000
#  - 2s - loss: 0.0109
# Epoch 557/2000
#  - 2s - loss: 0.0111
# Epoch 558/2000
#  - 2s - loss: 0.0117
# Epoch 559/2000
#  - 2s - loss: 0.0122
# Epoch 560/2000
#  - 2s - loss: 0.0130
# Epoch 561/2000
#  - 2s - loss: 0.0144
# Restoring model weights from the end of the best epoch.
# Epoch 00561: early stopping

# %%
from sklearn.externals import joblib 
path = "/content/drive/My Drive/model_cnnbilstm_spm_IRC.pkl"  
# Save the model as a pickle in a file 
joblib.dump(model, path)
# Out:
# ['/content/drive/My Drive/model_cnnbilstm_spm_IRC.pkl']

# %%
from sklearn.externals import joblib
model = joblib.load('F:\Weather Forecasting\Swastik_project\Models\model_cnnbilstm_spm_IRC.pkl')
# Out:
# Using TensorFlow backend.

# %%
x_input = array(X_test)
x_input = x_input.reshape((1, n_steps_in, n_features))
yhat = model.predict(x_input, verbose=2)
print((yhat[0]*std_spm)+mean_spm)
print((y_test*std_spm)+mean_spm)
# Out:
# [ 15.77465057  21.33368111  16.45056343  20.60182381  12.45544529
#   19.77458382  15.63081741  17.59766197  20.32873344  18.23159599
#   17.82210541  19.33264542  18.20191193  19.23058319  17.07241249
#   16.98010826  19.86132431  21.42939758  15.96133327  19.78939056
#   18.43794632]
# [ 16.  16.  17.  18.  18.  17.  19.  17.  18.  18.  20.  20.  18.  18.  19.
#   20.  17.  17.  17.  18.  17.]

# %%
X_test.shape
# Out:
# (100, 20)

# %%
# fig, ax = plt.subplots()
plt.title('Actual SPM values vs Predicted SPM values using CNN-BILSTM for IRC', fontsize = 20)
plt.xlabel('Day', fontsize = 20)
plt.ylabel('SPM Value', fontsize = 20)
plt.plot((yhat[0]*std_spm)+mean_spm, label = 'Predicted SPM Values', linewidth=3)
plt.plot((y_test*std_spm)+mean_spm, label = 'Actual SPM Values',  linewidth=3)
plt.legend(loc = 'lower center',frameon=True,  prop={"size":20});
plt.show()

# %%
x_new = []

for inp_val in X:
  x_input_new = inp_val.reshape((1, n_steps_in, n_features))
  y_newpred = model.predict(x_input_new, verbose = 1)
  x_new.append(y_newpred)
  
x_new = array(x_new)
# Out:
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 248us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0us/step

# %%
x_new1 = x_new[:, 0, :]
x_new1.shape
# Out:
# (789, 21)

# %%
print(x_new1.shape, y.shape)
# Out:
# (789, 21) (789, 21)

# %%
# from sklearn import svm
# from sklearn.svm import SVR

# svc = svm.SVC(kernel ='linear', C = 1).fit(x_ann_new, y)

# clf = SVR(C=1.0, epsilon=0.2)
# model_new = clf.fit(x_ann_new, y[:,0])

from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

regr_multirf = MultiOutputRegressor(SVR(kernel='rbf'))

#regr_multirf = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, max_depth=30, random_state=0))
regr_multirf.fit(x_new1, y)
# Out:
# MultiOutputRegressor(estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#            n_jobs=1)

# %%
from sklearn.externals import joblib 
path = "/content/drive/My Drive/model_cnnbilstm_RFRegressor_IRC.pkl"  
# Save the model as a pickle in a file 
joblib.dump(regr_multirf, path)
# Out:
# ['/content/drive/My Drive/model_cnnbilstm_RFRegressor_IRC.pkl']

# %%
regr_multirf = joblib.load('/content/drive/My Drive/model_cnnbilstm_RFRegressor_IRC.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-72-9c60bf22da1a> in <module>()
# ----> 1 regr_multirf = joblib.load('/content/drive/My Drive/model_cnnbilstm_RFRegressor_IRC.pkl')
#
# C:\Users\Swastik Mishra\Anaconda3\lib\site-packages\sklearn\externals\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     568             obj = _unpickle(fobj)
#     569     else:
# --> 570         with open(filename, 'rb') as f:
#     571             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     572                 if isinstance(fobj, _basestring):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/model_cnnbilstm_RFRegressor_IRC.pkl'

# %%
y_test.shape
y_test_new = y_test.reshape(y_test.shape[0], -1)

y_test_new.shape
y_test
# Out:
# array([ 0.03706463,  0.03706463,  0.2830197 ,  0.52897478,  0.52897478,
#         0.2830197 ,  0.77492986,  0.2830197 ,  0.52897478,  0.52897478,
#         1.02088493,  1.02088493,  0.52897478,  0.52897478,  0.77492986,
#         1.02088493,  0.2830197 ,  0.2830197 ,  0.2830197 ,  0.52897478,
#         0.2830197 ])

# %%
y_test_new = y_test_new.T
y_test_new
# Out:
# array([[ 0.03706463,  0.03706463,  0.2830197 ,  0.52897478,  0.52897478,
#          0.2830197 ,  0.77492986,  0.2830197 ,  0.52897478,  0.52897478,
#          1.02088493,  1.02088493,  0.52897478,  0.52897478,  0.77492986,
#          1.02088493,  0.2830197 ,  0.2830197 ,  0.2830197 ,  0.52897478,
#          0.2830197 ]])

# %%
yhat_new = regr_multirf.predict(y_test_new)

# %%
print(yhat_new)
print(y_test_new)
# Out:
# [[-0.04151699 -0.05282863  0.2178315   0.54204375  0.73094072  0.26818916
#    0.82909083  0.30232133  0.57753392  0.52512532  1.16647089  1.21235626
#    0.48612139  0.54557298  0.87413426  1.07538697  0.24578052  0.28265416
#    0.23777504  0.5959418   0.23964247]]
# [[ 0.03706463  0.03706463  0.2830197   0.52897478  0.52897478  0.2830197
#    0.77492986  0.2830197   0.52897478  0.52897478  1.02088493  1.02088493
#    0.52897478  0.52897478  0.77492986  1.02088493  0.2830197   0.2830197
#    0.2830197   0.52897478  0.2830197 ]]

# %%
#Denormalization
y_test_new = (y_test_new[0]*std_spm)+mean_spm 
yhat_new = (yhat_new[0]*std_spm)+mean_spm

# %%
print(yhat_new)
print(y_test_new)
# Out:
# [ 15.68050417  15.63451349  16.7349589   18.05313558  18.8211497
#   16.93970221  19.22020675  17.07847621  18.19743094  17.98434895
#   20.59192092  20.77848086  17.82576742  18.06748467  19.40334359
#   20.22159346  16.84859354  16.99851377  16.81604502  18.27227339
#   16.82363759]
# [ 16.  16.  17.  18.  18.  17.  19.  17.  18.  18.  20.  20.  18.  18.  19.
#   20.  17.  17.  17.  18.  17.]

# %%
# fig, ax = plt.subplots()
plt.title('Actual SPM values vs Predicted SPM values using CNN-BILSTM-SVR for IRC', fontsize = 20)
plt.xlabel('Day', fontsize = 20)
plt.ylabel('SPM Value', fontsize = 20)
plt.plot((yhat_new), label = 'Predicted SPM Values', linewidth=3)
plt.plot((y_test_new), label = 'Actual SPM Values', linewidth=3)
plt.legend(loc = 'lower center',frameon=True,  prop={"size":20});
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
def mean_absolute_percentage_error(y_true, y_pred): 
    # y_true, y_pred = check_arrays(y_true, y_pred)

    ## Note: does not handle mix 1d representation
    #if _is_1d(y_true): 
    #    y_true, y_pred = _check_1d_array(y_true, y_pred)

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


rms_new = sqrt(mean_squared_error(y_test_new, yhat_new))
print(rms_new)

mse_new = mean_squared_error(y_test_new, yhat_new)
print(mse_new)

mae_new = mean_absolute_error(y_test_new, yhat_new)
print(mae_new)

mape_new = mean_absolute_percentage_error(y_test_new, yhat_new)
print(mape_new)
# Out:
# 0.3412602723400361
# 0.116458573478
# 0.258043382362
# 1.41969801991

# %%
import csv
with open('cnn_bilstm_svr_irc.csv', 'w', newline='') as file:
    writer = csv.writer(file, delimiter = ',')
    writer.writerow(y_test_new)
    writer.writerow(yhat_new)
